# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data file paths
#input1 = 'temp300.dat'
#input2 = 'temp400.dat'
#input3 = 'temp500.dat'
#input4 = 'temp600.dat'
#input1 = 'BSe300.dat'
#input2 = 'BSe500.dat'
#input3 = 'BSe700.dat'
# Data file paths
#input1 = '200BSnew.dat'
#input1 = '200BSenew.dat'
#input2 = '300BSenew.dat'
#input2 = '300BSnew.dat'

#input1a = 'BSefiltered_2.dat'
#input2a = 'BSefiltered_3.dat'
#input3a = 'BSefiltered_4.dat'
#input4a = 'BSefiltered_5.dat'
#input5a = 'BSefiltered_6.dat'
#input6a = 'BSefiltered_7.dat'
#input7a = 'BSefiltered_8.dat'
#input8a = 'BSefiltered_9.dat'
#input9a = 'BSefiltered_10.dat'

input1 = 'BSe200.dat'
input2 = 'BSe300.dat'
input3 = 'BSe400.dat'
input4 = 'BSe500.dat'
input5 = 'BSe600.dat'
input6 = 'BSe700.dat'
input7 = 'BSe800.dat'
input8 = 'BSe900.dat'
input9 = 'BSe1000.dat'

input10 = '200newdataBS.dat'
input11 = '300newdataBS.dat'
input12 = '400newdataBS.dat'
input13 = '500newdataBS.dat'
input14 = '600newdataBS.dat'
input15 = '700newdataBS.dat'
input16 = '800newdataBS.dat'
input17 = '900newdataBS.dat'
input18 = '1000newdataBS.dat'

# Fermi energy and temperatures
#E_Fermi = 1.07375
E_Fermi= 1.92775
#T1 = 300
#T2 = 500
#T3 = 700

# Energy range
Emax = 1.5
Emin = -1.5

# Load the data
#data1 = pd.read_csv(input1, sep=r'\s+|\s+', engine='python')
#data2 = pd.read_csv(input2, sep=r'\s+|\s+', engine='python')
#data3 = pd.read_csv(input3, sep=r'\s+|\s+', engine='python')

#data1a = np.loadtxt(input1a)
#data2a = np.loadtxt(input2a)
#data3a = np.loadtxt(input3a)
#data4a = np.loadtxt(input4a)
#data5a = np.loadtxt(input5a)
#data6a = np.loadtxt(input6a)
#data7a = np.loadtxt(input7a)
#data8a = np.loadtxt(input8a)
#data9a = np.loadtxt(input9a)

data1 = np.loadtxt(input1)
data2 = np.loadtxt(input2)
data3 = np.loadtxt(input3)
data4 = np.loadtxt(input4)
data5 = np.loadtxt(input5)
data6 = np.loadtxt(input6)
data7 = np.loadtxt(input7)
data8 = np.loadtxt(input8)
data9 = np.loadtxt(input9)

data10 = np.loadtxt(input10)
data11 = np.loadtxt(input11)
data12 = np.loadtxt(input12)
data13 = np.loadtxt(input13)
data14 = np.loadtxt(input14)
data15 = np.loadtxt(input15)
data16 = np.loadtxt(input16)
data17 = np.loadtxt(input17)
data18 = np.loadtxt(input18)

#Seebeck1 = data1.iloc[:, 4] 
#Sigma1=data1.iloc[:, 5]
#Kappa1=data1.iloc[:, 7]
Seebeck1 = data1[:, 4] 
Seebeck2 = data2[:, 4]
Seebeck3 = data3[:, 4]
Seebeck4 = data4[:, 4]
Seebeck5 = data5[:, 4]
Seebeck6 = data6[:, 4]
Seebeck7 = data7[:, 4]
Seebeck8 = data8[:, 4]
Seebeck9 = data9[:, 4]

Sigma1=data1[:, 5]
Kappa1=data1[:, 7]

#Seebeck2 = data2.iloc[:, 4]
#Sigma2 = data2.iloc[:, 5]  
#Kappa2 = data2.iloc[:, 7] 

Sigma2 = data2[:, 5]  
Kappa2 = data2[:, 7]

#Seebeck3 = data3.iloc[:, 4]
#Sigma3 = data3.iloc[:, 5]  
#Kappa3 = data3.iloc[:, 7] 

Sigma3 = data3[:, 5]  
Kappa3 = data3[:, 7] 

Sigma4 = data4[:, 5]  
Kappa4 = data4[:, 7]

Sigma5 = data5[:, 5]  
Kappa5 = data5[:, 7]

Sigma6 = data6[:, 5]  
Kappa6 = data6[:, 7]

Sigma7 = data7[:, 5]  
Kappa7 = data7[:, 7]

Sigma8 = data8[:, 5]  
Kappa8 = data8[:, 7]

Seebeck9 = data9[:, 4]
Sigma9 = data9[:, 5]  
Kappa9 = data9[:, 7]

#X300 = (data1.iloc[:, 0] * 13.60565 - E_Fermi)
#X500 = (data2.iloc[:, 0] * 13.60565 - E_Fermi)
#X700 = (data3.iloc[:, 0] * 13.60565 - E_Fermi)
X200 = (data1[:, 0] * 13.60565 - E_Fermi )
X300 = (data2[:, 0] * 13.60565 - E_Fermi )
X400 = (data3[:, 0] * 13.60565 - E_Fermi )
X500 = (data4[:, 0] * 13.60565 - E_Fermi )
X600 = (data5[:, 0] * 13.60565 - E_Fermi )
X700 = (data6[:, 0] * 13.60565 - E_Fermi )
X800 = (data7[:, 0] * 13.60565 - E_Fermi )
X900 = (data8[:, 0] * 13.60565 - E_Fermi )
X1000 = (data9[:, 0] * 13.60565 - E_Fermi )

#x1 = np.clip(X300, -2, 2)
#x2 = np.clip(X500, -2, 2)
#x3 = np.clip(X700, -2, 2)

#y1 = np.where((x1 < -2) | (x1 > 2), np.nan, Seebeck1)
#y2 = np.where((x2 < -2) | (x2 > 2), np.nan, Seebeck2)
#y3 = np.where((x3 < -2) | (x3 > 2), np.nan, Seebeck3)

# Calculate Figure of Merit (FoM) values
#FoM1 = (Seebeck1 ** 2 * Sigma1 * 200) / (Kappa1)
#FoM2 = (Seebeck2 ** 2 * Sigma2 * 300) / (Kappa2)
#FoM3 = (Seebeck3 ** 2 * Sigma3 * 400) / (Kappa3)
#FoM4 = (Seebeck4 ** 2 * Sigma4 * 500) / (Kappa4)
#FoM5 = (Seebeck5 ** 2 * Sigma5 * 600) / (Kappa5)
#FoM6 = (Seebeck6 ** 2 * Sigma6 * 700) / (Kappa6)
#FoM7 = (Seebeck7 ** 2 * Sigma7 * 800) / (Kappa7)
#FoM8 = (Seebeck8 ** 2 * Sigma8 * 900) / (Kappa8)
#FoM9 = (Seebeck9 ** 2 * Sigma9 * 1000) / (Kappa9)

PF1 = (Seebeck1 ** 2 * Sigma1 )
PF2 = (Seebeck2 ** 2 * Sigma2 )
PF3 = (Seebeck3 ** 2 * Sigma3 )
PF4 = (Seebeck4 ** 2 * Sigma4 )
PF5 = (Seebeck5 ** 2 * Sigma5 )
PF6 = (Seebeck6 ** 2 * Sigma6 )
PF7 = (Seebeck7 ** 2 * Sigma7 )
PF8 = (Seebeck8 ** 2 * Sigma8 )
PF9 = (Seebeck9 ** 2 * Sigma9 )
# Create the plot
fig, ax = plt.subplots(figsize=(14, 10), sharex= True)

plt.plot(X200, PF1, color='blue', label='300 Kelvin')
plt.plot(X300, PF2, color='red', label='500 Kelvin')
plt.plot(X400, PF3, color='green', label='700 Kelvin')
plt.plot(X500, PF4, color='blue', label='300 Kelvin')
plt.plot(X600, PF5, color='red', label='500 Kelvin')
plt.plot(X700, PF6, color='green', label='700 Kelvin')
plt.plot(X800, PF7, color='blue', label='300 Kelvin')
plt.plot(X900, PF8, color='red', label='500 Kelvin')
plt.plot(X1000, PF9, color='green', label='700 Kelvin')

#plt.plot(x1, y1, color='blue', label='300 Kelvin')
#plt.plot(x2, y2, color='red', label='600 Kelvin')
#plt.plot(x3, y3, color='green', label='900 Kelvin')

#plt.plot(X300, Kappa3, color='blue', label='300 Kelvin')
#plt.plot(X600, Kappa6, color='red', label='600 Kelvin')
#plt.plot(X900, Kappa9, color='green', label='900 Kelvin')

#plt.xlabel('$E - E_{\mathrm{F}}$ (eV)',fontsize = 30)
#plt.ylabel('Seebeck V/K',fontsize = 30)
#plt.title('Seebeck V/K vs. $E - E_{\mathrm{F}}$',fontsize = 30)
#plt.xlim([-5, 5])
#plt.ylim(0, 1e+1)
#plt.legend(fontsize = 13)

#print the data
max_FoM1 = max(PF1)
max_FoM2 = max(PF2)
max_FoM3 = max(PF3)
max_FoM4 = max(PF4)
max_FoM5 = max(PF5)
max_FoM6 = max(PF6)
max_FoM7 = max(PF7)
max_FoM8 = max(PF8)
max_FoM9 = max(PF9)

print("Maximum FoM value for 200 Kelvin:", max_FoM1)
print("Maximum FoM value for 300 Kelvin:", max_FoM2)
print("Maximum FoM value for 400 Kelvin:", max_FoM3)
print("Maximum FoM value for 500 Kelvin:", max_FoM4)
print("Maximum FoM value for 600 Kelvin:", max_FoM5)
print("Maximum FoM value for 700 Kelvin:", max_FoM6)
print("Maximum FoM value for 800 Kelvin:", max_FoM7)
print("Maximum FoM value for 900 Kelvin:", max_FoM8)
print("Maximum FoM value for 1000 Kelvin:", max_FoM9)

max_s1 = max(Seebeck1)
max_s2 = max(Seebeck5)
max_s3 = max(Seebeck8)
#min_s1 = min(Seebeck1)
#min_s2 = min(Seebeck2)
#min_s3 = min(Seebeck3)

print("Maximum seebeck value for 300 Kelvin:", max_s1)
print("Maximum seebeck value for 600 Kelvin:", max_s2)
print("Maximum seebeck value for 900 Kelvin:", max_s3)
#print("Maximum seebeck value for 300 Kelvin:", min_s1)
#print("Maximum seebeck value for 500 Kelvin:", min_s2)
#print("Maximum seebeck value for 700 Kelvin:", min_s3)

# Find the maximum and minimum values along the first axis (rows)
max_values1 = np.max(data1[:,5])
min_values1 = np.min(data1[:,5])
max_values2 = np.max(data2[:,5])
min_values2 = np.min(data2[:,5])
max_values3 = np.max(data3[:,5])
min_values3 = np.min(data3[:,5])
max_values4 = np.max(data4[:,5])
min_values4 = np.min(data4[:,5])
max_values5 = np.max(data5[:,5])
min_values5 = np.min(data5[:,5])
max_values6 = np.max(data6[:,5])
min_values6 = np.min(data6[:,5])
max_values7 = np.max(data7[:,5])
min_values7 = np.min(data7[:,5])
max_values8 = np.max(data8[:,5])
min_values8 = np.min(data8[:,5])
max_values9 = np.max(data9[:,5])
min_values9 = np.min(data9[:,5])

print("Maximum values along the axis1:", max_values1)
print("Minimum values along the axis:", min_values1)
print("Maximum values along the axis2:", max_values2)
print("Minimum values along the axis:", min_values2)
print("Maximum values along the axis3:", max_values3)
print("Minimum values along the axis:", min_values3)
print("Maximum values along the axis4:", max_values4)
print("Minimum values along the axis:", min_values4)
print("Maximum values along the axis5:", max_values5)
print("Minimum values along the axis:", min_values5)
print("Maximum values along the axis6:", max_values6)
print("Minimum values along the axis:", min_values6)
print("Maximum values along the axis7:", max_values7)
print("Minimum values along the axis:", min_values7)
print("Maximum values along the axis8:", max_values8)
print("Minimum values along the axis:", min_values8)
print("Maximum values along the axis9:", max_values9)
print("Minimum values along the axis:", min_values9)

max_values10 = np.max(data11[:,7])
min_values10 = np.min(data11[:,7])
max_values11 = np.max(data11[:,7])
min_values11 = np.min(data11[:,7])
max_values12 = np.max(data12[:,7])
min_values12 = np.min(data12[:,7])
max_values13 = np.max(data13[:,7])
min_values13 = np.min(data13[:,7])
max_values14 = np.max(data14[:,7])
min_values14 = np.min(data14[:,7])
max_values15 = np.max(data15[:,7])
min_values15 = np.min(data15[:,7])
max_values16 = np.max(data16[:,7])
min_values16 = np.min(data16[:,7])
max_values17 = np.max(data17[:,7])
min_values17 = np.min(data17[:,7])
max_values18 = np.max(data18[:,7])
min_values18 = np.min(data18[:,7])
#max_values19 = np.max(data19[:,7])
#min_values19 = np.min(data19[:,7])

print("Maximum values along the axis10:", max_values10)
print("Minimum values along the axis:", min_values10)
print("Maximum values along the axis11:", max_values11)
print("Minimum values along the axis:", min_values11)
print("Maximum values along the axis12:", max_values12)
print("Minimum values along the axis:", min_values12)
print("Maximum values along the axis13:", max_values13)
print("Minimum values along the axis:", min_values13)
print("Maximum values along the axis14:", max_values14)
print("Minimum values along the axis:", min_values14)
print("Maximum values along the axis15:", max_values15)
print("Minimum values along the axis:", min_values15)
print("Maximum values along the axis16:", max_values16)
print("Minimum values along the axis:", min_values16)
print("Maximum values along the axis17:", max_values17)
print("Minimum values along the axis:", min_values17)
print("Maximum values along the axis18:", max_values18)
print("Minimum values along the axis:", min_values18)
#print("Maximum values along the axis9:", max_values19)
#print("Minimum values along the axis:", min_values19)

#print("data :",y1)

plt.show()
# Out:
# Maximum FoM value for 200 Kelvin: 2463113659770.003
# Maximum FoM value for 300 Kelvin: 2403500093978.456
# Maximum FoM value for 400 Kelvin: 1926828153819.0
# Maximum FoM value for 500 Kelvin: 1460875620249.621
# Maximum FoM value for 600 Kelvin: 1135375215808.4001
# Maximum FoM value for 700 Kelvin: 883607951293.6133
# Maximum FoM value for 800 Kelvin: 958431280348.7144
# Maximum FoM value for 900 Kelvin: 1033900744909.7599
# Maximum FoM value for 1000 Kelvin: 1106161771486.2092
# Maximum seebeck value for 300 Kelvin: 0.00147697
# Maximum seebeck value for 600 Kelvin: 0.00155903
# Maximum seebeck value for 900 Kelvin: 0.00158638
# Maximum values along the axis1: 5.4383e+20
# Minimum values along the axis: 0.0
# Maximum values along the axis2: 4.7317e+20
# Minimum values along the axis: 0.0
# Maximum values along the axis3: 4.50401e+20
# Minimum values along the axis: 0.0
# Maximum values along the axis4: 4.37842e+20
# Minimum values along the axis: 0.0
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

#input data suhu
X = [200,300,400,500,600,700,800,900,1000 ]
#input data seebeck BSe dan BS
SBSe = [1477,1559, 1539 , 1575, 1559, 1582, 1569,  1461, 1257 ]
SBS = [1573.67, 1573.67, 1539.46, 1559.98, 1573.67, 1583.44, 1565.12, 1571.49,  1349.1]

EBSe = [543.83, 473.17, 450.401, 437.842, 431.39, 429.044, 427.223, 425.218, 422.969 ]
EBS  = [778.392, 778.392, 699.186, 661.912,  636.501, 616.968, 601.269, 589.476, 579.504]

KBSe = [23.6824, 34.6546, 44.0888, 52.914, 61.7169, 70.2883, 78.6989, 86.9679, 95.1085]
KBS  = [45.7502, 45.7502, 59.043, 71.8361, 83.6996, 95.0844, 106.148, 116.714, 127.605]

ZTBSe = [100.19, 99.56, 96.79, 102.63, 101.93,  106.94, 106.91, 85.89,70.27]
ZTBS  = [84.26, 126.4, 140.32,113.88, 111, 112.99,113.89, 109.44, 82.64 ]

#PF BSe = []

#ZTBSe = []
#ZTBS  = []

#Plot the data seebeck
fig, ax = plt.subplots(figsize=(14, 10), sharex= True)
plt.plot(X, SBSe, 'p-',color='#e377c2', label='BSe')
plt.plot(X, SBS, 'p-',color='#ff7f0e', label='BS')

plt.xlabel('Suhu(K)',fontsize = 30)
plt.ylabel('Seebeck $\mu$V/K',fontsize = 30)
plt.title('Seebeck $\mu$V/K vs. Suhu (k)',fontsize = 30)
plt.gca().xaxis.set_tick_params(labelsize=14)
plt.gca().yaxis.set_tick_params(labelsize=14)
plt.legend(fontsize = 13)

#Plot the data electrical
fig, ax = plt.subplots(figsize=(14, 10), sharex= True)
plt.plot(X, EBSe, 'p-',color='#e377c2', label='BSe')
plt.plot(X, EBS, 'p-',color='#ff7f0e', label='BS')

plt.xlabel('Suhu(K)',fontsize = 30)
plt.ylabel('Electrical Conductivity $\sigma$/τ($10^{18}$S/ms)',fontsize = 30)
plt.title('Electrical Conductivity $\sigma$/τ($10^{18}$S/ms) vs. Suhu (k)',fontsize = 30)
plt.gca().xaxis.set_tick_params(labelsize=14)
plt.gca().yaxis.set_tick_params(labelsize=14)
plt.legend(fontsize = 13)

#Plot the data termal
fig, ax = plt.subplots(figsize=(14, 10), sharex= True)
plt.plot(X, KBSe, 'p-',color='#e377c2', label='BSe')
plt.plot(X, KBS, 'p-',color='#ff7f0e', label='BS')

plt.xlabel('Suhu(K)',fontsize = 30)
plt.ylabel('Thermal Conductivity $K_e$/τ($10^{14}$W/mKs)',fontsize = 30)
plt.title('Thermal Conductivity $K_e$/τ($10^{14}$W/mKs) vs. Suhu (k)',fontsize = 30)
plt.gca().xaxis.set_tick_params(labelsize=14)
plt.gca().yaxis.set_tick_params(labelsize=14)
plt.legend(fontsize = 13)

#Plot the data zte
fig, ax = plt.subplots(figsize=(14, 10), sharex= True)
plt.plot(X, ZTBSe, 'p-',color='#e377c2', label='BSe')
plt.plot(X, ZTBS, 'p-',color='#ff7f0e', label='BS')

plt.xlabel('Suhu(K)',fontsize = 30)
plt.ylabel('$ZT_{e}$',fontsize = 30)
plt.title('$ZT_{e}$vs. Suhu (k)',fontsize = 30)
plt.gca().xaxis.set_tick_params(labelsize=14)
plt.gca().yaxis.set_tick_params(labelsize=14)
plt.legend(fontsize = 13)

#Plot the power factor
fig, ax = plt.subplots(figsize=(14, 10), sharex= True)
plt.plot(X, ZTBSe, 'p-',color='#e377c2', label='BSe')
plt.plot(X, ZTBS, 'p-',color='#ff7f0e', label='BS')

plt.xlabel('Suhu(K)',fontsize = 30)
plt.ylabel('Power Factor (µW/mK²)',fontsize = 30)
plt.title('Power Factor (µW/mK²) vs Suhu (K)',fontsize = 30)
plt.gca().xaxis.set_tick_params(labelsize=14)
plt.gca().yaxis.set_tick_params(labelsize=14)
plt.legend(fontsize = 13)

#plot merge
fig, ax = plt.subplots(2,2, figsize=(28, 20), sharex= True)
ax[1][0].plot(X, SBSe, 'p-',color='#e377c2', label='BSe')
ax[1][0].plot(X, SBS, 'p-',color='#ff7f0e', label='BS')
ax[1][0].set_xlabel('Suhu(K)',fontsize = 30)
ax[1][0].set_ylabel('Seebeck $\mu$V/K',fontsize = 30)
ax[1][0].set_title('Seebeck $\mu$V/K vs. Suhu (k)',fontsize = 30)
ax[1][0].xaxis.set_tick_params(labelsize=14)
ax[1][0].yaxis.set_tick_params(labelsize=14)
ax[1][0].legend(fontsize = 13)

ax[0][1].plot(X, EBSe, 'p-',color='#e377c2', label='BSe')
ax[0][1].plot(X, EBS, 'p-',color='#ff7f0e', label='BS')
ax[0][1].set_xlabel('Suhu(K)',fontsize = 30)
ax[0][1].set_ylabel('Electrical Conductivity $\sigma$/τ($10^{18}$S/ms)',fontsize = 30)
ax[0][1].set_title('Electrical Conductivity $\sigma$/τ($10^{18}$S/ms) vs. Suhu (k)',fontsize = 30)
ax[0][1].xaxis.set_tick_params(labelsize=14)
ax[0][1].yaxis.set_tick_params(labelsize=14)
ax[0][1].legend(fontsize = 13)

ax[0][0].plot(X, KBSe, 'p-',color='#e377c2', label='BSe')
ax[0][0].plot(X, KBS, 'p-',color='#ff7f0e', label='BS')
ax[0][0].set_xlabel('Suhu(K)',fontsize = 30)
ax[0][0].set_ylabel('Thermal Conductivity $K_e$/τ($10^{14}$W/mKs)',fontsize = 30)
ax[0][0].set_title('Thermal Conductivity $K_e$/τ($10^{14}$W/mKs) vs. Suhu (k)',fontsize = 30)
ax[0][0].xaxis.set_tick_params(labelsize=14)
ax[0][0].yaxis.set_tick_params(labelsize=14)
ax[0][0].legend(fontsize = 13)

ax[1][1].plot(X, ZTBSe, 'p-',color='#e377c2', label='BSe')
ax[1][1].plot(X, ZTBS, 'p-',color='#ff7f0e', label='BS')
ax[1][1].set_xlabel('Suhu(K)',fontsize = 30)
ax[1][1].set_ylabel('$ZT_{e}$',fontsize = 30)
ax[1][1].set_title('$ZT_{e}$ vs. Suhu (k)',fontsize = 30)
ax[1][1].xaxis.set_tick_params(labelsize=14)
ax[1][1].yaxis.set_tick_params(labelsize=14)
ax[1][1].legend(fontsize = 13)

plt.show()
# Out:
# <>:30: SyntaxWarning: invalid escape sequence '\m'
# <>:31: SyntaxWarning: invalid escape sequence '\m'
# <>:42: SyntaxWarning: invalid escape sequence '\s'
# <>:43: SyntaxWarning: invalid escape sequence '\s'
# <>:89: SyntaxWarning: invalid escape sequence '\m'
# <>:90: SyntaxWarning: invalid escape sequence '\m'
# <>:98: SyntaxWarning: invalid escape sequence '\s'
# <>:99: SyntaxWarning: invalid escape sequence '\s'
# <>:30: SyntaxWarning: invalid escape sequence '\m'
# <>:31: SyntaxWarning: invalid escape sequence '\m'
# <>:42: SyntaxWarning: invalid escape sequence '\s'
# <>:43: SyntaxWarning: invalid escape sequence '\s'
# <>:89: SyntaxWarning: invalid escape sequence '\m'
# <>:90: SyntaxWarning: invalid escape sequence '\m'
# <>:98: SyntaxWarning: invalid escape sequence '\s'
# <>:99: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_976\4015657633.py:30: SyntaxWarning: invalid escape sequence '\m'
# ...
